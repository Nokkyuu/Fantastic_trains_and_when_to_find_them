# %%
import requests
import pandas as pd
# Replace both api keys are created on the via the website

client_id = '5cf21bb577a46a3f0263677e5bee0969'
client_secret = '0229d92a983df1a6681e56ba6a390135'
url = "https://apis.deutschebahn.com/db-api-marketplace/apis/ris-stations/v1/stations?limit=100" #here will go more optional stuff like what kind of stations, how many etc (default: 100)
# Set up headers with API key - 
headers={
        "DB-Api-Key": client_secret,
        "DB-Client-Id": client_id,
        "accept": "application/vnd.de.db.ris+json"
            }
# Make a GET request to the API
response = requests.get(url, headers=headers)
# Check if the request was success
if response.status_code == 200:
    data = response.json()
else:
    print(f"Failed to fetch data: {response.status_code}")
    data = None

# %%
print(data["stations"][0]["address"])
# Out:
# {'street': 'Bahnhofstr.', 'houseNumber': '2a', 'postalCode': '52064', 'city': 'Aachen', 'state': 'Nordrhein-Westfalen', 'country': 'DE'}

# %%
data_copy = data
nopos = 0
index = 0
for i in data["stations"]:
    data_copy["stations"][index]["names"] = data_copy["stations"][index]["names"]["DE"]["name"]

    if 'position' in data_copy["stations"][index].keys():
        data_copy["stations"][index]["position_long"] = data_copy["stations"][index]["position"]["longitude"]
        data_copy["stations"][index]["position_lat"] = data_copy["stations"][index]["position"]["latitude"]
    else:
        pass
        #data_copy["stations"].pop(index)
    if 'address' in data_copy["stations"][index].keys():
        data_copy["stations"][index]["street"] = data_copy["stations"][index]["address"]["street"]
        data_copy["stations"][index]["postalCode"] = data_copy["stations"][index]["address"]["postalCode"]
        data_copy["stations"][index]["city"] = data_copy["stations"][index]["address"]["city"]
        data_copy["stations"][index]["state"] = data_copy["stations"][index]["address"]["state"]
    else:
        pass
    index = index+1

# %%
df = pd.DataFrame(data_copy["stations"])
df.head()
# Out:
#   stationID                 names metropolis  \
# 0         1            Aachen Hbf         {}
# 1      1000  Burkhardswalde-Maxen         {}
# 2      1001        Burkhardtsdorf         {}
# 3      1002              Bürstadt         {}
# 4      1005               Buschow         {}
#
#                                              address stationCategory  \
# 0  {'street': 'Bahnhofstr.', 'houseNumber': '2a',...      CATEGORY_2
# 1  {'street': 'Gesundbrunnen', 'houseNumber': '60...      CATEGORY_7
# 2  {'street': 'Bahnhofstraße', 'postalCode': '092...      CATEGORY_6
# 3  {'street': 'Bahnhofsallee', 'houseNumber': '17...      CATEGORY_6
# 4  {'street': 'Bahnhofstr.', 'houseNumber': '28',...      CATEGORY_6
#
#   availableTransports availableLocalServices transportAssociations  \
# 0                  []                     []                    []
# 1                  []                     []                    []
# 2                  []                     []                    []
# 3                  []                     []                    []
# 4                  []                     []                    []
#
#                                                owner countryCode  \
# 0  {'name': 'DB InfraGO Personenbahnhöfe', 'organ...          DE
# 1  {'name': 'DB InfraGO Personenbahnhöfe', 'organ...          DE
# 2  {'name': 'DB Regio-Netze', 'organisationalUnit...          DE
# 3  {'name': 'DB InfraGO Personenbahnhöfe', 'organ...          DE
# 4  {'name': 'DB InfraGO Personenbahnhöfe', 'organ...          DE
#
#         timeZone                                           position  \
# 0  Europe/Berlin       {'longitude': 6.091499, 'latitude': 50.7678}
# 1  Europe/Berlin  {'longitude': 13.8383692, 'latitude': 50.9251456}
# 2  Europe/Berlin                                                NaN
# 3  Europe/Berlin     {'longitude': 8.458188, 'latitude': 49.645769}
# 4  Europe/Berlin    {'longitude': 12.628996, 'latitude': 52.592203}
#
#               validFrom  position_long  position_lat         street  \
# 0  2019-01-01T00:00:00Z       6.091499     50.767800    Bahnhofstr.
# 1  2019-01-01T00:00:00Z      13.838369     50.925146  Gesundbrunnen
# 2  1970-01-01T00:00:00Z            NaN           NaN  Bahnhofstraße
# 3  2019-01-01T00:00:00Z       8.458188     49.645769  Bahnhofsallee
# 4  2019-01-01T00:00:00Z      12.628996     52.592203    Bahnhofstr.
#
#   postalCode                       city                state
# 0      52064                     Aachen  Nordrhein-Westfalen
# 1      01809  Müglitztal-Burkhardswalde              Sachsen
# 2      09235             Burkhardtsdorf              Sachsen
# 3      68642                   Bürstadt               Hessen
# 4      14715   Märkisch Luch OT Buschow          Brandenburg

# %%
df.shape
# Out:
# (100, 19)

# %%
# Display basic information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   stationID               100 non-null    object
#  1   names                   100 non-null    object
#  2   metropolis              100 non-null    object
#  3   address                 100 non-null    object
#  4   stationCategory         100 non-null    object
#  5   availableTransports     100 non-null    object
#  6   availableLocalServices  100 non-null    object
#  7   transportAssociations   100 non-null    object
#  8   owner                   100 non-null    object
#  9   countryCode             100 non-null    object
#  10  timeZone                100 non-null    object
#  11  position                92 non-null     object
#  12  validFrom               100 non-null    object
#  13  position_long           92 non-null     float64
#  14  position_lat            92 non-null     float64
#  15  street                  100 non-null    object
#  16  postalCode              100 non-null    object
#  17  city                    100 non-null    object
#  18  state                   100 non-null    object
# dtypes: float64(2), object(17)
# memory usage: 15.0+ KB

# %%
df.columns
# Out:
# Index(['stationID', 'names', 'metropolis', 'address', 'stationCategory',
#        'availableTransports', 'availableLocalServices',
#        'transportAssociations', 'owner', 'countryCode', 'timeZone', 'position',
#        'validFrom', 'position_long', 'position_lat', 'street', 'postalCode',
#        'city', 'state'],
#       dtype='object')

# %%
df_new = df[[
    'stationID', 'names', 'street', 'postalCode',
    'city', 'state',
    #'metropolis', 
    #'address', 
    'stationCategory',
    #'availableTransports', 'availableLocalServices',
    #'transportAssociations', 'owner', 'countryCode', 'timeZone', 'position','validFrom', 
    'position_long', 'position_lat',]
    ]

# %%
df_new.head()
# Out:
#   stationID                 names         street postalCode  \
# 0         1            Aachen Hbf    Bahnhofstr.      52064
# 1      1000  Burkhardswalde-Maxen  Gesundbrunnen      01809
# 2      1001        Burkhardtsdorf  Bahnhofstraße      09235
# 3      1002              Bürstadt  Bahnhofsallee      68642
# 4      1005               Buschow    Bahnhofstr.      14715
#
#                         city                state stationCategory  \
# 0                     Aachen  Nordrhein-Westfalen      CATEGORY_2
# 1  Müglitztal-Burkhardswalde              Sachsen      CATEGORY_7
# 2             Burkhardtsdorf              Sachsen      CATEGORY_6
# 3                   Bürstadt               Hessen      CATEGORY_6
# 4   Märkisch Luch OT Buschow          Brandenburg      CATEGORY_6
#
#    position_long  position_lat
# 0       6.091499     50.767800
# 1      13.838369     50.925146
# 2            NaN           NaN
# 3       8.458188     49.645769
# 4      12.628996     52.592203

# %%
df_new.shape
# Out:
# (100, 9)

# %%
df_new.info
# Out:
# <bound method DataFrame.info of    stationID                  names            street postalCode  \
# 0          1             Aachen Hbf       Bahnhofstr.      52064
# 1       1000   Burkhardswalde-Maxen     Gesundbrunnen      01809
# 2       1001         Burkhardtsdorf     Bahnhofstraße      09235
# 3       1002               Bürstadt     Bahnhofsallee      68642
# 4       1005                Buschow       Bahnhofstr.      14715
# ..       ...                    ...               ...        ...
# 95      1122  Dannenwalde (Gransee)     Bahnhofstraße      16775
# 96      1123               Darching       Bahnhofstr.      83626
# 97      1125           Darlingerode       Bahnhofstr.      38871
# 98      1126          Darmstadt Hbf   Am Hauptbahnhof      64293
# 99      1127         Darmstadt Nord  Frankfurter Str.      64293
#
#                          city                state stationCategory  \
# 0                      Aachen  Nordrhein-Westfalen      CATEGORY_2
# 1   Müglitztal-Burkhardswalde              Sachsen      CATEGORY_7
# 2              Burkhardtsdorf              Sachsen      CATEGORY_6
# 3                    Bürstadt               Hessen      CATEGORY_6
# 4    Märkisch Luch OT Buschow          Brandenburg      CATEGORY_6
# ..                        ...                  ...             ...
# 95                    Gransee          Brandenburg      CATEGORY_6
# 96                     Valley               Bayern      CATEGORY_6
# 97               Darlingerode       Sachsen-Anhalt      CATEGORY_7
# 98                  Darmstadt               Hessen      CATEGORY_2
# 99                  Darmstadt               Hessen      CATEGORY_5
#
#     position_long  position_lat
# 0        6.091499     50.767800
# 1       13.838369     50.925146
# 2             NaN           NaN
# 3        8.458188     49.645769
# 4       12.628996     52.592203
# ..            ...           ...
# 95      13.180801     53.079756
# 96      11.777253     47.870798
# 97      10.733037     51.849080
# 98       8.629636     49.872503
# 99       8.654311     49.892136
#
# [100 rows x 9 columns]>

# %%
df_new.head(100)
# Out:
#    stationID                  names            street postalCode  \
# 0          1             Aachen Hbf       Bahnhofstr.      52064
# 1       1000   Burkhardswalde-Maxen     Gesundbrunnen      01809
# 2       1001         Burkhardtsdorf     Bahnhofstraße      09235
# 3       1002               Bürstadt     Bahnhofsallee      68642
# 4       1005                Buschow       Bahnhofstr.      14715
# ..       ...                    ...               ...        ...
# 95      1122  Dannenwalde (Gransee)     Bahnhofstraße      16775
# 96      1123               Darching       Bahnhofstr.      83626
# 97      1125           Darlingerode       Bahnhofstr.      38871
# 98      1126          Darmstadt Hbf   Am Hauptbahnhof      64293
# 99      1127         Darmstadt Nord  Frankfurter Str.      64293
#
#                          city                state stationCategory  \
# 0                      Aachen  Nordrhein-Westfalen      CATEGORY_2
# 1   Müglitztal-Burkhardswalde              Sachsen      CATEGORY_7
# 2              Burkhardtsdorf              Sachsen      CATEGORY_6
# 3                    Bürstadt               Hessen      CATEGORY_6
# 4    Märkisch Luch OT Buschow          Brandenburg      CATEGORY_6
# ..                        ...                  ...             ...
# 95                    Gransee          Brandenburg      CATEGORY_6
# 96                     Valley               Bayern      CATEGORY_6
# 97               Darlingerode       Sachsen-Anhalt      CATEGORY_7
# 98                  Darmstadt               Hessen      CATEGORY_2
# 99                  Darmstadt               Hessen      CATEGORY_5
#
#     position_long  position_lat
# 0        6.091499     50.767800
# 1       13.838369     50.925146
# 2             NaN           NaN
# 3        8.458188     49.645769
# 4       12.628996     52.592203
# ..            ...           ...
# 95      13.180801     53.079756
# 96      11.777253     47.870798
# 97      10.733037     51.849080
# 98       8.629636     49.872503
# 99       8.654311     49.892136
#
# [100 rows x 9 columns]

# %%
#df_new.to_csv("data/fromAPI/stations.csv")
