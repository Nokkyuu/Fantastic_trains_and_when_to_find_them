# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("../data/fromAPI/cleaned_hourly_all.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561368 entries, 0 to 561367
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     561368 non-null  object
#  1   train                  495264 non-null  object
#  2   path                   508263 non-null  object
#  3   eva_nr                 561368 non-null  int64
#  4   category               561368 non-null  int64
#  5   name                   561368 non-null  object
#  6   state                  561368 non-null  object
#  7   city                   561368 non-null  object
#  8   zip                    561368 non-null  int64
#  9   long                   561368 non-null  float64
#  10  lat                    561368 non-null  float64
#  11  arrival_plan           508263 non-null  object
#  12  departure_plan         511444 non-null  object
#  13  arrival_change         437802 non-null  object
#  14  departure_change       428594 non-null  object
#  15  arrival_delay_m        561368 non-null  int64
#  16  depature_delay_m       561368 non-null  int64
#  17  hour                   561368 non-null  int64
#  18  arrival_delay_check    561368 non-null  object
#  19  departure_delay_check  561368 non-null  object
# dtypes: float64(2), int64(6), object(12)
# memory usage: 85.7+ MB

# %%
df.describe()
# Out:
#              eva_nr       category            zip           long  \
# count  5.613680e+05  561368.000000  561368.000000  561368.000000
# mean   8.017228e+06       3.737265   46530.271131      10.159702
# std    3.098976e+04       1.125038   28240.538954       2.261001
# min    8.000001e+06       1.000000    1067.000000       6.070715
# 25%    8.000963e+06       3.000000   19322.000000       8.477775
# 50%    8.004128e+06       4.000000   47137.000000       9.926072
# 75%    8.010159e+06       5.000000   71032.000000      12.068507
# max    8.098360e+06       5.000000   99974.000000      14.979080
#
#                  lat  arrival_delay_m  depature_delay_m           hour
# count  561368.000000    561368.000000     561368.000000  561368.000000
# mean       50.882864         1.310858          1.205113      21.356616
# std         1.789527         4.622308          4.287337      13.403683
# min        47.411032         0.000000          0.000000       0.000000
# 25%        49.354245         0.000000          0.000000       9.000000
# 50%        51.065899         0.000000          0.000000      21.000000
# 75%        52.477617         1.000000          1.000000      32.000000
# max        54.906839       373.000000        370.000000      44.000000

# %%
df.columns
# Out:
# Index(['ID', 'train', 'path', 'eva_nr', 'category', 'name', 'state', 'city',
#        'zip', 'long', 'lat', 'arrival_plan', 'departure_plan',
#        'arrival_change', 'departure_change', 'arrival_delay_m',
#        'depature_delay_m', 'hour', 'arrival_delay_check',
#        'departure_delay_check'],
#       dtype='object')

# %%
df.head()
# Out:
#                                    ID train  \
# 0    4083473720689476753-2406231250-4    20
# 1  -8892239479013746475-2406231212-14    20
# 2    3772983581833112391-2406231337-1    33
# 3   -7760689325071259199-2406231337-1    29
# 4    3762663024269879642-2406231318-1     9
#
#                                                 path   eva_nr  category  \
# 0    Stolberg(Rheinl)Hbf|Eilendorf|Aachen-Rothe Erde  8000001         2
# 1  Stolberg(Rheinl)Hbf Gl.44|Eschweiler-St.Jöris|...  8000001         2
# 2                                                NaN  8000001         2
# 3                                                NaN  8000001         2
# 4                                                NaN  8000001         2
#
#          name                state    city    zip      long      lat  \
# 0  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 1  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 2  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 3  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 4  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
#
#           arrival_plan       departure_plan       arrival_change  \
# 0  2024-06-23 13:01:00  2024-06-23 13:02:00  2024-06-23 13:03:00
# 1  2024-06-23 13:00:00  2024-06-23 13:01:00  2024-06-23 13:05:00
# 2                  NaN  2024-06-23 13:37:00                  NaN
# 3                  NaN  2024-06-23 13:37:00                  NaN
# 4                  NaN  2024-06-23 13:18:00                  NaN
#
#       departure_change  arrival_delay_m  depature_delay_m  hour  \
# 0  2024-06-23 13:04:00                2                 2     0
# 1  2024-06-23 13:06:00                5                 5     0
# 2                  NaN                0                 0     0
# 3                  NaN                0                 0     0
# 4  2024-06-23 13:18:00                0                 0     0
#
#   arrival_delay_check departure_delay_check
# 0             on_time               on_time
# 1             on_time               on_time
# 2             on_time               on_time
# 3             on_time               on_time
# 4             on_time               on_time

# %%
#df = df.drop(columns="Unnamed: 0", axis=1)

# %%
df.head()
# Out:
#                                    ID train  \
# 0    4083473720689476753-2406231250-4    20
# 1  -8892239479013746475-2406231212-14    20
# 2    3772983581833112391-2406231337-1    33
# 3   -7760689325071259199-2406231337-1    29
# 4    3762663024269879642-2406231318-1     9
#
#                                                 path   eva_nr  category  \
# 0    Stolberg(Rheinl)Hbf|Eilendorf|Aachen-Rothe Erde  8000001         2
# 1  Stolberg(Rheinl)Hbf Gl.44|Eschweiler-St.Jöris|...  8000001         2
# 2                                                NaN  8000001         2
# 3                                                NaN  8000001         2
# 4                                                NaN  8000001         2
#
#          name                state    city    zip      long      lat  \
# 0  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 1  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 2  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 3  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 4  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
#
#           arrival_plan       departure_plan       arrival_change  \
# 0  2024-06-23 13:01:00  2024-06-23 13:02:00  2024-06-23 13:03:00
# 1  2024-06-23 13:00:00  2024-06-23 13:01:00  2024-06-23 13:05:00
# 2                  NaN  2024-06-23 13:37:00                  NaN
# 3                  NaN  2024-06-23 13:37:00                  NaN
# 4                  NaN  2024-06-23 13:18:00                  NaN
#
#       departure_change  arrival_delay_m  depature_delay_m  hour  \
# 0  2024-06-23 13:04:00                2                 2     0
# 1  2024-06-23 13:06:00                5                 5     0
# 2                  NaN                0                 0     0
# 3                  NaN                0                 0     0
# 4  2024-06-23 13:18:00                0                 0     0
#
#   arrival_delay_check departure_delay_check
# 0             on_time               on_time
# 1             on_time               on_time
# 2             on_time               on_time
# 3             on_time               on_time
# 4             on_time               on_time

# %%
df.isnull().sum()
# Out:
# ID                            0
# train                     66104
# path                      53105
# eva_nr                        0
# category                      0
# name                          0
# state                         0
# city                          0
# zip                           0
# long                          0
# lat                           0
# arrival_plan              53105
# departure_plan            49924
# arrival_change           123566
# departure_change         132774
# arrival_delay_m               0
# depature_delay_m              0
# hour                          0
# arrival_delay_check           0
# departure_delay_check         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.histplot(data=df, x="arrival_delay_m", bins=2000)
plt.title("Histogram Arrival delay")
plt.xlabel("Delay")
plt.ylabel("Frequency")
plt.ylim(0, 2500)
plt.xlim(-20, 40)
plt.show()

# %%
df_val = df[df["arrival_delay_m"] > 0]

sns.histplot(data=df_val, x="arrival_delay_m", bins=1000)
plt.title("Histogram Arrival delay")
plt.xlabel("Delay")
plt.ylabel("Frequency")
plt.ylim(0, 30000)
plt.xlim(0, 40)
plt.show()

# %%
df.head()
# Out:
#                                    ID train  \
# 0    4083473720689476753-2406231250-4    20
# 1  -8892239479013746475-2406231212-14    20
# 2    3772983581833112391-2406231337-1    33
# 3   -7760689325071259199-2406231337-1    29
# 4    3762663024269879642-2406231318-1     9
#
#                                                 path   eva_nr  category  \
# 0    Stolberg(Rheinl)Hbf|Eilendorf|Aachen-Rothe Erde  8000001         2
# 1  Stolberg(Rheinl)Hbf Gl.44|Eschweiler-St.Jöris|...  8000001         2
# 2                                                NaN  8000001         2
# 3                                                NaN  8000001         2
# 4                                                NaN  8000001         2
#
#          name                state    city    zip      long      lat  \
# 0  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 1  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 2  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 3  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
# 4  Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678
#
#           arrival_plan       departure_plan       arrival_change  \
# 0  2024-06-23 13:01:00  2024-06-23 13:02:00  2024-06-23 13:03:00
# 1  2024-06-23 13:00:00  2024-06-23 13:01:00  2024-06-23 13:05:00
# 2                  NaN  2024-06-23 13:37:00                  NaN
# 3                  NaN  2024-06-23 13:37:00                  NaN
# 4                  NaN  2024-06-23 13:18:00                  NaN
#
#       departure_change  arrival_delay_m  depature_delay_m  hour  \
# 0  2024-06-23 13:04:00                2                 2     0
# 1  2024-06-23 13:06:00                5                 5     0
# 2                  NaN                0                 0     0
# 3                  NaN                0                 0     0
# 4  2024-06-23 13:18:00                0                 0     0
#
#   arrival_delay_check departure_delay_check
# 0             on_time               on_time
# 1             on_time               on_time
# 2             on_time               on_time
# 3             on_time               on_time
# 4             on_time               on_time

# %%
df_stations = df.groupby("name", as_index=False).mean(numeric_only=True)

# %%
df_stations.head()
# Out:
#                 name     eva_nr  category      zip       long        lat  \
# 0         Aachen Hbf  8000001.0       2.0  52064.0   6.091499  50.767800
# 1      Aachen Schanz  8070704.0       5.0  52064.0   6.073840  50.769862
# 2        Aachen West  8000404.0       5.0  52072.0   6.070715  50.780360
# 3  Aachen-Rothe Erde  8000406.0       4.0  52066.0   6.116475  50.770202
# 4          Aalen Hbf  8000002.0       3.0  73430.0  10.096271  48.841013
#
#    arrival_delay_m  depature_delay_m       hour
# 0         1.961017          0.844068  21.266102
# 1         0.996587          1.126280  20.825939
# 2         1.128000          1.146667  21.418667
# 3         1.688525          1.680328  21.094262
# 4         1.310559          0.822981  21.130435

# %% [markdown]
# # Arrival Delay

# %%
df_stations[df_stations["arrival_delay_m"] < 0].shape
# Out:
# (0, 9)

# %%
df_stations[df_stations["arrival_delay_m"] < 0] = 0

# %%
#Plotting the stations with size indicator for the delay
fig = px.scatter_mapbox(df_stations, lon='long', lat='lat', hover_name='name', size_max=20, zoom=10,
                        size="arrival_delay_m"
                        
)

# Update layout and setting the map
fig.update_layout(mapbox_style="carto-positron",
                  mapbox_center={"lat": 51.1657, "lon": 10.4515},  # Centered on Germany
                  mapbox_zoom=5,
                  width = 700,
                  height = 800)

# Show the plot
fig.show()

# %%
#Plotting the stations 
fig = px.scatter_mapbox(df_stations, lon='long', lat='lat', hover_name='name', size_max=20, zoom=10,
                       # size="arrival_delay_m"
                        
)

# Update layout and setting the map
fig.update_layout(mapbox_style="open-street-map",
                  mapbox_center={"lat": 51.1657, "lon": 10.4515},  # Centered on Germany
                  mapbox_zoom=5,
                  width = 700,
                  height = 800)

# Show the plot
fig.show()

# %% [markdown]
# # Departure Delay

# %%
#for the departure delay
df_stations[df_stations["depature_delay_m"] < 0] = 0

# %%
#Plotting the stations with size indicator for the delay
fig = px.scatter_mapbox(df_stations, lon='long', lat='lat', hover_name='name', size_max=20, zoom=10,
                        size="depature_delay_m"
                        
)

# Update layout and setting the map
fig.update_layout(mapbox_style="carto-positron",
                  mapbox_center={"lat": 51.1657, "lon": 10.4515},  # Centered on Germany
                  mapbox_zoom=5,
                  width = 700,
                  height = 800)

# Show the plot
fig.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561368 entries, 0 to 561367
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     561368 non-null  object
#  1   train                  495264 non-null  object
#  2   path                   508263 non-null  object
#  3   eva_nr                 561368 non-null  int64
#  4   category               561368 non-null  int64
#  5   name                   561368 non-null  object
#  6   state                  561368 non-null  object
#  7   city                   561368 non-null  object
#  8   zip                    561368 non-null  int64
#  9   long                   561368 non-null  float64
#  10  lat                    561368 non-null  float64
#  11  arrival_plan           508263 non-null  object
#  12  departure_plan         511444 non-null  object
#  13  arrival_change         437802 non-null  object
#  14  departure_change       428594 non-null  object
#  15  arrival_delay_m        561368 non-null  int64
#  16  depature_delay_m       561368 non-null  int64
#  17  hour                   561368 non-null  int64
#  18  arrival_delay_check    561368 non-null  object
#  19  departure_delay_check  561368 non-null  object
# dtypes: float64(2), int64(6), object(12)
# memory usage: 85.7+ MB

# %%
df2 = df[["eva_nr", "category", "zip", "arrival_delay_m", "depature_delay_m", "hour"]]
df_corr = df2.corr()
sns.heatmap(data=df_corr, annot=True)
# Out:
# <Axes: >

# %%
sns.jointplot(data=df_stations, x="depature_delay_m", y="arrival_delay_m")
