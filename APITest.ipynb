# %%
import requests
import pandas as pd
# Replace both api keys are created on the via the website

client_id = '5cf21bb577a46a3f0263677e5bee0969'
client_secret = '0229d92a983df1a6681e56ba6a390135'
url = "https://apis.deutschebahn.com/db-api-marketplace/apis/ris-stations/v1/stations"
# Set up headers with API key - here will go more optional stuff like what kind of stations, how many etc (default: 100)
headers={
        "DB-Api-Key": client_secret,
        "DB-Client-Id": client_id,
            }
# Make a GET request to the API
response = requests.get(url, headers=headers)
# Check if the request was success
if response.status_code == 200:
    data = response.json()
else:
    print(f"Failed to fetch data: {response.status_code}")
    data = None

# %%
print(data["stations"])
# Out:
# [{'stationID': '1', 'names': {'DE': {'name': 'Aachen Hbf'}}, 'metropolis': {}, 'address': {'street': 'Bahnhofstr.', 'houseNumber': '2a', 'postalCode': '52064', 'city': 'Aachen', 'state': 'Nordrhein-Westfalen', 'country': 'DE'}, 'stationCategory': 'CATEGORY_2', 'availableTransports': [], 'availableLocalServices': [], 'transportAssociations': [], 'owner': {'name': 'DB InfraGO Personenbahnhöfe', 'organisationalUnit': {'id': 4, 'name': 'RB West', 'nameShort': 'RB West'}}, 'countryCode': 'DE', 'timeZone': 'Europe/Berlin', 'position': {'longitude': 6.091499, 'latitude': 50.7678}, 'validFrom': '2019-01-01T00:00:00Z'}, {'stationID': '1000', 'names': {'DE': {'name': 'Burkhardswalde-Maxen'}}, 'metropolis': {}, 'address': {'street': 'Gesundbrunnen', 'houseNumber': '60c', 'postalCode': '01809', 'city': 'Müglitztal-Burkhardswalde', 'state': 'Sachsen', 'country': 'DE'}, 'stationCategory': 'CATEGORY_7', 'availableTransports': [], 'availableLocalServices': [], 'transportAssociations': [], 'owner': {
# ...

# %%
df = pd.DataFrame(data["stations"])
df.head()
# Out:
#   stationID                                     names metropolis  \
# 0         1            {'DE': {'name': 'Aachen Hbf'}}         {}
# 1      1000  {'DE': {'name': 'Burkhardswalde-Maxen'}}         {}
# 2      1001        {'DE': {'name': 'Burkhardtsdorf'}}         {}
# 3      1002              {'DE': {'name': 'Bürstadt'}}         {}
# 4      1005               {'DE': {'name': 'Buschow'}}         {}
#
#                                              address stationCategory  \
# 0  {'street': 'Bahnhofstr.', 'houseNumber': '2a',...      CATEGORY_2
# 1  {'street': 'Gesundbrunnen', 'houseNumber': '60...      CATEGORY_7
# 2  {'street': 'Bahnhofstraße', 'postalCode': '092...      CATEGORY_6
# 3  {'street': 'Bahnhofsallee', 'houseNumber': '17...      CATEGORY_6
# 4  {'street': 'Bahnhofstr.', 'houseNumber': '28',...      CATEGORY_6
#
#   availableTransports availableLocalServices transportAssociations  \
# 0                  []                     []                    []
# ...

# %%
df.shape
# Out:
# (100, 13)

# %%
# Display basic information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   stationID               100 non-null    object
#  1   names                   100 non-null    object
#  2   metropolis              100 non-null    object
#  3   address                 100 non-null    object
#  4   stationCategory         100 non-null    object
#  5   availableTransports     100 non-null    object
#  6   availableLocalServices  100 non-null    object
#  7   transportAssociations   100 non-null    object
#  8   owner                   100 non-null    object
#  9   countryCode             100 non-null    object
#  10  timeZone                100 non-null    object
#  11  position                92 non-null     object
#  12  validFrom               100 non-null    object
# dtypes: object(13)
# memory usage: 10.3+ KB
